# %% [markdown]
# ### Searching & Sorting Algorithms

# %% [markdown]
# ####  Linear search for a single occurrence – Complexity O(n) (Tìm kiếm tuyến tính cho một lần xuất hiện)

# %%
def linear_search(arr, value):
    for i in range(len(arr)):
        if arr[i]==value:
            return i
    return -1
arr = list(map(int,input().split()))
value = int(input())
print(linear_search(arr, value))
# Out:
# 4

# %% [markdown]
# ####  Linear search for multiple occurrence – Complexity O(n) (Tìm kiếm tuyến tính cho nhiều lần xuất hiện)

# %%
def linear_search_all(arr, value):
    indices = []
    for i in range(len(arr)):
        if arr[i] == value:
            indices.append(i)
    return indices
arr = list(map(int, input().split()))
value = int(input())
print(*linear_search_all(arr, value)) #Cách 1
result = linear_search_all(arr,value)
print(" ".join(str(x) for x in result)) #Cách 2
# Out:
# 1 3 11
# 1 3 11

# %% [markdown]
# ####  Binary search for a single occurrence – Complexity O(log n) (Tìm kiếm nhị phân cho một lần xuất hiện)

# %%
def binary_search(arr, value):
    arr.sort(reverse = False) #Sắp xếp trước
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right)//2
        if arr[mid] == value:
            return mid
        elif arr[mid] < value:
            left = mid + 1
        else:
            right = mid - 1
    return - 1
arr = list(map(int,input().split()))
value = int(input())
print(binary_search(arr,value))
# Out:
# 3

# %% [markdown]
#  #### Bubble sort with early stopping – Complexity O(n2) (Sắp xếp nổi bọt với dừng sớm – Độ phức tạp O(n2))

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0,n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr
arr = list(map(int,input().split()))
print(bubble_sort(arr))
# Out:
# [1, 3, 4, 5, 5, 6, 7, 8, 9]

# %%
s = "1 2 3 4 5"
print(s.split())
for i in s.split():
    print(i,end="")
# Out:
# ['1', '2', '3', '4', '5']
# 12345

# %% [markdown]
# #### Selection sort – Complexity O(n2) (Sắp xếp chọn – Độ phức tạp O(n2))

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1,n):
            if arr[min_idx]> arr[j]:
                min_idx = j
        arr[i],arr[min_idx] = arr[min_idx], arr[i]
    return arr
arr = list(map(int,input().split()))
print(*selection_sort(arr))
# Out:
# 10 13 21 24 65

# %% [markdown]
# ####  Insertion sort – Complexity O(n2)

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i  - 1
        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -=1
        arr[j+1] = key
    return arr
print(insertion_sort([9,5,1,4]))
# Out:
# [1, 4, 5, 9]

# %% [markdown]
# #### Merge sort – Complexity O(n log n)

# %%
def merge_sort(arr):  
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]
    sorted_left = merge_sort(left)
    sorted_right = merge_sort(right)
    return merge(sorted_left, sorted_right)
def merge(left,right):
    res = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            res.append(left[i])
            i += 1
        else:
            res.append(right[j])
            j += 1
    res.extend(left[i:])
    res.extend(right[j:])
    return res
arr = list(map(int,input().split()))
print(merge_sort(arr))
# Out:
# [7, 24, 39, 40]

# %% [markdown]
# ####  Quick sort

# %%
def partition(arr,low,high):
    pivot = arr[high]
    i = low - 1
    for j in range(low,high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
        arr[i+1], arr[high] = arr[high], arr[i+1]
        return i + 1
def quicksort(arr,low,high):
    if low < high:
        pi = partition(arr, low, high)
        quicksort(arr,low,pi-1)
        quicksort(arr,pi+1,high)

# %%
def quick_sort(arr):
    if len(arr) <=1:
        return arr
    #Chọn phần tử chốt (pivot) là phần tử ở chính giữa
    pivot = arr[len(arr)//2]
    left = [x for x in arr if x < pivot] #Nhóm các số nhỏ hơn pivot
    mid = [x for x in arr if x == pivot] # bằng pivot
    right = [x for x in arr if x > pivot] # lớn hơn pivot
    #Gọi hàm đệ quy cho hai nửa trái, phải
    return quick_sort(left) + mid + quick_sort(right)
arr = list(map(int,input().split()))
print(quick_sort(arr))
# Out:
# [3, 4, 5, 6, 6, 8, 8, 9, 12]
